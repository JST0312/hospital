# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('data/hospital.csv',encoding='cp949')
pd.set_option('display.max.colwidth', 10)

# %%
df
# Out:
#       시군명       사업장명     인허가일자   소재지도로명주소    소재지지번주소  소재지우편번호         위도  \
# 0     가평군   가평산속요양병원  20121008  경기도 가평...  경기도 가평...  12445.0  37.788938
# 1     가평군  가평푸른숲요양병원  20170901  경기도 가평...  경기도 가평...  12440.0  37.840847
# 2     가평군   감인노인전문병원  20080715  경기도 가평...  경기도 가평...  12440.0  37.840949
# 3     가평군     강변요양병원  20200306  경기도 가평...  경기도 가평...  12428.0  37.747333
# 4     가평군     국군청평병원  19940523  경기도 가평...  경기도 가평...  12452.0  37.743691
# ...   ...        ...       ...        ...        ...      ...        ...
# 1344  화성시   화성제일요양병원  20140521  경기도 화성...  경기도 화성...  18401.0  37.211213
# 1345  화성시   화성제일한방병원  20221025  경기도 화성...  경기도 화성...  18256.0  37.217753
# 1346  화성시     화성한방병원  20191227  경기도 화성...  경기도 화성...  18606.0  37.116396
# 1347  화성시   화성해인요양병원  20160422  경기도 화성...  경기도 화성...  18289.0  37.249533
# 1348  화성시      희망찬병원  20080905  경기도 화성...  경기도 화성...  18399.0  37.213417
#
#              경도  인허가취소일자 영업상태명  ...    의료기관종별명  의료인수  입원실수    병상수        총면적  \
# ...

# %%
df=df.drop(columns='소재지면적정보')

# %%
df['특수구급차대수'].isnull().sum()
# Out:
# 12

# %%
df['허가병상수'].isnull().sum()
# Out:
# 12

# %%
df
# Out:
#       시군명       사업장명     인허가일자   소재지도로명주소    소재지지번주소  소재지우편번호         위도  \
# 0     가평군   가평산속요양병원  20121008  경기도 가평...  경기도 가평...  12445.0  37.788938
# 1     가평군  가평푸른숲요양병원  20170901  경기도 가평...  경기도 가평...  12440.0  37.840847
# 2     가평군   감인노인전문병원  20080715  경기도 가평...  경기도 가평...  12440.0  37.840949
# 3     가평군     강변요양병원  20200306  경기도 가평...  경기도 가평...  12428.0  37.747333
# 4     가평군     국군청평병원  19940523  경기도 가평...  경기도 가평...  12452.0  37.743691
# ...   ...        ...       ...        ...        ...      ...        ...
# 1344  화성시   화성제일요양병원  20140521  경기도 화성...  경기도 화성...  18401.0  37.211213
# 1345  화성시   화성제일한방병원  20221025  경기도 화성...  경기도 화성...  18256.0  37.217753
# 1346  화성시     화성한방병원  20191227  경기도 화성...  경기도 화성...  18606.0  37.116396
# 1347  화성시   화성해인요양병원  20160422  경기도 화성...  경기도 화성...  18289.0  37.249533
# 1348  화성시      희망찬병원  20080905  경기도 화성...  경기도 화성...  18399.0  37.213417
#
#              경도  인허가취소일자 영업상태명  ...    의료기관종별명  의료인수  입원실수    병상수        총면적  \
# ...

# %%
df['영업상태명']
# Out:
# 0       영업중
# 1       영업중
# 2        폐업
# 3       영업중
# 4        폐업
#        ...
# 1344     폐업
# 1345    영업중
# 1346    영업중
# 1347    영업중
# 1348    영업중
# Name: 영업상태명, Length: 1349, dtype: object

# %%
df
# Out:
#       시군명       사업장명     인허가일자                             소재지지번주소  소재지우편번호  \
# 0     가평군   가평산속요양병원  20121008                  경기도 가평군 상면 항사리 2번지  12445.0
# 1     가평군  가평푸른숲요양병원  20170901               경기도 가평군 상면 봉수리 49-4번지  12440.0
# 2     가평군   감인노인전문병원  20080715                 경기도 가평군 상면 봉수리 49-4  12440.0
# 3     가평군     강변요양병원  20200306               경기도 가평군 가평읍 금대리 585번지  12428.0
# 4     가평군     국군청평병원  19940523       경기도 가평군 청평면 청평리 567번지 21호 사서함  12452.0
# ...   ...        ...       ...                                 ...      ...
# 1344  화성시   화성제일요양병원  20140521  경기도 화성시 진안동 512번지 1호 2층, 3층 일부, 5층  18401.0
# 1345  화성시   화성제일한방병원  20221025               경기도 화성시 남양읍 북양리 692-1  18256.0
# 1346  화성시     화성한방병원  20191227           경기도 화성시 향남읍 하길리 1465번지 2호  18606.0
# 1347  화성시   화성해인요양병원  20160422             경기도 화성시 매송면 원평리 50-13번지  18289.0
# 1348  화성시      희망찬병원  20080905                 경기도 화성시 진안동 868-9번지  18399.0
#
# ...

# %%
address= df['소재지지번주소']
print(address.head(10))
# Out:
# 0               경기도 가평군 상면 항사리 2번지
# 1            경기도 가평군 상면 봉수리 49-4번지
# 2              경기도 가평군 상면 봉수리 49-4
# 3            경기도 가평군 가평읍 금대리 585번지
# 4    경기도 가평군 청평면 청평리 567번지 21호 사서함
# 5         경기도 가평군 조종면 하판리 540번지 2호
# 6            경기도 가평군 설악면 송산리 460번지
# 7            경기도 가평군 설악면 송산리 460번지
# 8           경기도 가평군 상면 봉수리 49번지 4호
# 9            경기도 가평군 청평면 441번지 43호
# Name: 소재지지번주소, dtype: object

# %%
address
# Out:
# 0

# %%
for address in range(len(address)):
    a = address.split(' ')
    address[address]= " ".join(a[0:4])
print(address)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [89], line 1
# ----> 1 for address in range(len(address)):
#       2     a = address.split(' ')
#       3     address[address]= " ".join(a[0:4])
#
# TypeError: object of type 'int' has no len()

# %%
address.split('',4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [94], line 1
# ----> 1 address.split('',4)
#
# AttributeError: 'int' object has no attribute 'split'

# %%
df=pd.options.display.max_colwidth = None

# %%
df=pd.reset_option('^display.', silent=True)

# %%
df

# %%
df

# %%
df.count()
# Out:
# 시군명          1349
# 사업장명         1349
# 인허가일자        1349
# 소재지도로명주소     1338
# 소재지지번주소      1348
# 소재지우편번호      1339
# 위도           1340
# 경도           1340
# 인허가취소일자         8
# 영업상태명        1349
# 폐업일자          443
# 소재지시설전화번호    1309
# 소재지면적정보         0
# 업태구분명정보      1349
# X좌표값         1155
# Y좌표값         1155
# 의료기관종별명      1337
# 의료인수         1337
# 입원실수         1337
# 병상수          1337
# 총면적          1336
# 진료과목내용       1337
# 진료과목내용정보     1337
# 특수구급차대수      1337
# 일반구급차대수      1337
# 허가병상수        1337
# dtype: int64

# %%
df.describe()
# Out:
#               인허가일자       소재지우편번호           위도           경도       인허가취소일자  \
# count  1.349000e+03   1349.000000  1349.000000  1349.000000  1.349000e+03
# mean   2.010178e+07  14062.607116    37.200921   126.133460  1.193060e+05
# std    8.937815e+04   2814.244224     3.057778    10.342908  1.545229e+06
# min    1.900010e+07      0.000000     0.000000     0.000000  0.000000e+00
# 25%    2.007012e+07  11793.000000    37.288398   126.799078  0.000000e+00
# 50%    2.011053e+07  14519.000000    37.410914   126.964775  0.000000e+00
# 75%    2.016121e+07  16334.000000    37.647462   127.112500  0.000000e+00
# max    2.022121e+07  18626.000000    38.091111   127.780777  2.016012e+07
#
#                폐업일자  소재지면적정보           X좌표값           Y좌표값         의료인수  \
# count  1.349000e+03   1349.0    1349.000000    1349.000000  1349.000000
# mean   6.615143e+06      0.0  169729.916980  375807.253935    46.247591
# std    9.463769e+06      0.0   71586.777865  155734.283895   179.160992
# ...

# %%
df=df.fillna(0)

# %%
df['의료인수'].hist(rwidth = 0.8 , bins = 20)
plt.show()

# %%
df.corr().fillna
# Out:
# <bound method DataFrame.fillna of                위도        경도      폐업일자      X좌표값      Y좌표값      의료인수      입원실수  \
# 위도       1.000000  0.997001 -0.116167  0.169580  0.180252  0.018901  0.055282
# 경도       0.997001  1.000000 -0.118470  0.176410  0.169616  0.019318  0.055358
# 폐업일자    -0.116167 -0.118470  1.000000 -0.045245 -0.024090 -0.143959 -0.292155
# X좌표값     0.169580  0.176410 -0.045245  1.000000  0.955265 -0.072696 -0.037215
# Y좌표값     0.180252  0.169616 -0.024090  0.955265  1.000000 -0.071006 -0.047633
# 의료인수     0.018901  0.019318 -0.143959 -0.072696 -0.071006  1.000000  0.809645
# 입원실수     0.055282  0.055358 -0.292155 -0.037215 -0.047633  0.809645  1.000000
# 병상수      0.041678  0.040515 -0.244364 -0.029363 -0.035147  0.741845  0.919856
# 특수구급차대수       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 일반구급차대수       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 허가병상수         NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
df
# Out:
#       시군명       사업장명     인허가일자                               소재지도로명주소  \
# 0     가평군   가평산속요양병원  20121008                   경기도 가평군 상면 대보간선로 889
# 1     가평군  가평푸른숲요양병원  20170901                  경기도 가평군 상면 물골길 262-23
# 2     가평군   감인노인전문병원  20080715            경기도 가평군 상면 물골길 262-23 (봉수리)
# 3     가평군     강변요양병원  20200306                  경기도 가평군 가평읍 북한강변로 160
# 4     가평군     국군청평병원  19940523                    경기도 가평군 청평면 경춘로 926
# ...   ...        ...       ...                                    ...
# 1344  화성시   화성제일요양병원  20140521  경기도 화성시 효행로 990, 2층,3층,5층 (진안동, 비젼월드)
# 1345  화성시   화성제일한방병원  20221025            경기도 화성시 남양읍 남양로920번길 12, 4층
# 1346  화성시     화성한방병원  20191227            경기도 화성시 향남읍 발안양감로 187, 4,5층
# 1347  화성시   화성해인요양병원  20160422                경기도 화성시 매송면 화성로 2407-15
# 1348  화성시      희망찬병원  20080905                경기도 화성시 병점중앙로 174 (진안동)
#
#              위도          경도 영업상태명      소재지시설전화번호       업태구분명정보           X좌표값  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [191], line 4
#       1 c =df
#       3 # Run all nodes interactively
# ----> 4 c.InteractiveShell.ast_node_interactivity = "all"
#
# File ~\anaconda3\envs\YH\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'InteractiveShell'

# %%
df
# Out:
#       시군명       사업장명   소재지도로명주소         위도         경도 영업상태명  소재지시설전화번호  \
# 0     가평군   가평산속요양병원  경기도 가평...  37.788938  127.40...   영업중  031-58...
# 1     가평군  가평푸른숲요양병원  경기도 가평...  37.840847  127.30...   영업중  1661-9099
# 2     가평군   감인노인전문병원  경기도 가평...  37.840949  127.30...    폐업  031-58...
# 3     가평군     강변요양병원  경기도 가평...  37.747333  127.52...   영업중  031-58...
# 4     가평군     국군청평병원  경기도 가평...  37.743691  127.42...    폐업  031-58...
# ...   ...        ...        ...        ...        ...   ...        ...
# 1344  화성시   화성제일요양병원  경기도 화성...  37.211213  127.03...    폐업  031-52...
# 1345  화성시   화성제일한방병원  경기도 화성...  37.217753  126.83...   영업중  031-80...
# 1346  화성시     화성한방병원  경기도 화성...  37.116396  126.91...   영업중  031-35...
# 1347  화성시   화성해인요양병원  경기도 화성...  37.249533  126.92...   영업중  031-29...
# 1348  화성시      희망찬병원  경기도 화성...  37.213417  127.03...   영업중  031-22...
#
#         업태구분명정보       X좌표값       Y좌표값    의료기관종별명  의료인수  입원실수    병상수  \
# ...

# %%
df = df.fillna(0)

# %%
df
# Out:
#       시군명       사업장명   소재지도로명주소         위도         경도 영업상태명  소재지시설전화번호  \
# 0     가평군   가평산속요양병원  경기도 가평...  37.788938  127.40...   영업중  031-58...
# 1     가평군  가평푸른숲요양병원  경기도 가평...  37.840847  127.30...   영업중  1661-9099
# 2     가평군   감인노인전문병원  경기도 가평...  37.840949  127.30...    폐업  031-58...
# 3     가평군     강변요양병원  경기도 가평...  37.747333  127.52...   영업중  031-58...
# 4     가평군     국군청평병원  경기도 가평...  37.743691  127.42...    폐업  031-58...
# ...   ...        ...        ...        ...        ...   ...        ...
# 1344  화성시   화성제일요양병원  경기도 화성...  37.211213  127.03...    폐업  031-52...
# 1345  화성시   화성제일한방병원  경기도 화성...  37.217753  126.83...   영업중  031-80...
# 1346  화성시     화성한방병원  경기도 화성...  37.116396  126.91...   영업중  031-35...
# 1347  화성시   화성해인요양병원  경기도 화성...  37.249533  126.92...   영업중  031-29...
# 1348  화성시      희망찬병원  경기도 화성...  37.213417  127.03...   영업중  031-22...
#
#         업태구분명정보       X좌표값       Y좌표값    의료기관종별명  의료인수  입원실수    병상수  \
# ...

# %%
df.size
# Out:
# 22933

# %%
# %%html
# <style>
# table {float:right}
# </style>
# Out:
# <style>
# table {float:right}
# </style>

# %%
df1=df

# %%
np.set_printoptions(threshold=np.inf,linewidth=np.inf)

# %%
pd.set_option('display.max_rows', None)
# col 생략 없이 출력
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#        시군명       사업장명   소재지도로명주소         위도         경도 영업상태명  소재지시설전화번호  \
# 0      가평군   가평산속요양병원  경기도 가평...  37.788938  127.40...   영업중  031-58...
# 1      가평군  가평푸른숲요양병원  경기도 가평...  37.840847  127.30...   영업중  1661-9099
# 2      가평군   감인노인전문병원  경기도 가평...  37.840949  127.30...    폐업  031-58...
# 3      가평군     강변요양병원  경기도 가평...  37.747333  127.52...   영업중  031-58...
# 4      가평군     국군청평병원  경기도 가평...  37.743691  127.42...    폐업  031-58...
# 5      가평군  노체리안드리...  경기도 가평...  37.884883  127.35...   영업중  031-58...
# 6      가평군  에이치제이매...  경기도 가평...  37.691127  127.52...   영업중  031-58...
# 7      가평군  에이치제이매...  경기도 가평...  37.691127  127.52...   영업중  031-58...
# 8      가평군  연제의료생활...  경기도 가평...  37.840949  127.30...  직권폐업  031-58...
# 9      가평군     청평우리병원  경기도 가평...  37.737202  127.41...   영업중  031-58...
# 10     가평군  청평푸른숲한방병원  경기도 가평...  37.663614  127.38...    폐업  1661-9099
# 11     가평군   청평활명요양병원  경기도 가평...  37.663666  127.38...   영업중  031-58...
# ...

# %%
df1
# Out:
#        시군명       사업장명   소재지도로명주소         위도         경도 영업상태명  소재지시설전화번호  \
# 0      가평군   가평산속요양병원  경기도 가평...  37.788938  127.40...   영업중  031-58...
# 1      가평군  가평푸른숲요양병원  경기도 가평...  37.840847  127.30...   영업중  1661-9099
# 2      가평군   감인노인전문병원  경기도 가평...  37.840949  127.30...    폐업  031-58...
# 3      가평군     강변요양병원  경기도 가평...  37.747333  127.52...   영업중  031-58...
# 4      가평군     국군청평병원  경기도 가평...  37.743691  127.42...    폐업  031-58...
# 5      가평군  노체리안드리...  경기도 가평...  37.884883  127.35...   영업중  031-58...
# 6      가평군  에이치제이매...  경기도 가평...  37.691127  127.52...   영업중  031-58...
# 7      가평군  에이치제이매...  경기도 가평...  37.691127  127.52...   영업중  031-58...
# 8      가평군  연제의료생활...  경기도 가평...  37.840949  127.30...  직권폐업  031-58...
# 9      가평군     청평우리병원  경기도 가평...  37.737202  127.41...   영업중  031-58...
# 10     가평군  청평푸른숲한방병원  경기도 가평...  37.663614  127.38...    폐업  1661-9099
# 11     가평군   청평활명요양병원  경기도 가평...  37.663666  127.38...   영업중  031-58...
# ...

# %%
df.to_csv(hospital)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [235], line 1
# ----> 1 df.to_csv(hospital)
#
# NameError: name 'hospital' is not defined

# %%
df.loc[['가평군']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [43], line 1
# ----> 1 df.loc[['가평군']]
#
# File ~\anaconda3\envs\YH\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\YH\lib\site-packages\pandas\core\indexing.py:1194, in _LocIndexer._getitem_axis(self, key, axis)
#    1191     if hasattr(key, "ndim") and key.ndim > 1:
#    1192         raise ValueError("Cannot index with multidimensional key")
# -> 1194     return self._getitem_iterable(key, axis=axis)
#    1196 # nested tuple slicing
#    1197 if is_nested_tuple(key, labels):
#
# ...

# %%
df.isin(['가평군'])
# Out:
#         시군명   사업장명  인허가일자  소재지도로명주소  소재지지번주소  소재지우편번호     위도     경도  인허가취소일자  \
# 0      True  False  False     False    False    False  False  False    False
# 1      True  False  False     False    False    False  False  False    False
# 2      True  False  False     False    False    False  False  False    False
# 3      True  False  False     False    False    False  False  False    False
# 4      True  False  False     False    False    False  False  False    False
# ...     ...    ...    ...       ...      ...      ...    ...    ...      ...
# 1344  False  False  False     False    False    False  False  False    False
# 1345  False  False  False     False    False    False  False  False    False
# 1346  False  False  False     False    False    False  False  False    False
# 1347  False  False  False     False    False    False  False  False    False
# 1348  False  False  False     False    False    False  False  False    False
#
# ...

# %%
df['시군명'].value_counts()
# Out:
# 안산시     129
# 고양시     110
# 부천시     106
# 수원시      97
# 용인시      91
# 성남시      76
# 시흥시      72
# 화성시      68
# 파주시      63
# 남양주시     61
# 의정부시     54
# 평택시      49
# 김포시      48
# 안양시      45
# 양주시      28
# 구리시      25
# 하남시      24
# 오산시      23
# 군포시      22
# 안성시      20
# 광명시      18
# 양평군      17
# 동두천시     17
# 이천시      16
# 광주시      16
# 포천시      16
# 의왕시      12
# 가평군      12
# 여주시      11
# 연천군       2
# 과천시       1
# Name: 시군명, dtype: int64

# %%
 df[df['시군명'].isin(['가평군'])]
# Out:
#     시군명       사업장명     인허가일자   소재지도로명주소    소재지지번주소  소재지우편번호         위도  \
# 0   가평군   가평산속요양병원  20121008  경기도 가평...  경기도 가평...  12445.0  37.788938
# 1   가평군  가평푸른숲요양병원  20170901  경기도 가평...  경기도 가평...  12440.0  37.840847
# 2   가평군   감인노인전문병원  20080715  경기도 가평...  경기도 가평...  12440.0  37.840949
# 3   가평군     강변요양병원  20200306  경기도 가평...  경기도 가평...  12428.0  37.747333
# 4   가평군     국군청평병원  19940523  경기도 가평...  경기도 가평...  12452.0  37.743691
# 5   가평군  노체리안드리...  19951218  경기도 가평...  경기도 가평...  12432.0  37.884883
# 6   가평군  에이치제이매...  20030517  경기도 가평...  경기도 가평...  12461.0  37.691127
# 7   가평군  에이치제이매...  20030518  경기도 가평...  경기도 가평...  12461.0  37.691127
# 8   가평군  연제의료생활...  20100622  경기도 가평...  경기도 가평...  12440.0  37.840949
# 9   가평군     청평우리병원  20050215  경기도 가평...  경기도 가평...  12451.0  37.737202
# 10  가평군  청평푸른숲한방병원  20141205  경기도 가평...  경기도 가평...  12458.0  37.663614
# 11  가평군   청평활명요양병원  20170814  경기도 가평...  경기도 가평...  12458.0  37.663666
#
# ...

# %%
df2
# Out:
#             lat        lon
# 0     37.788938  127.40...
# 1     37.840847  127.30...
# 2     37.840949  127.30...
# 3     37.747333  127.52...
# 4     37.743691  127.42...
# ...         ...        ...
# 1344  37.211213  127.03...
# 1345  37.217753  126.83...
# 1346  37.116396  126.91...
# 1347  37.249533  126.92...
# 1348  37.213417  127.03...
#
# [1349 rows x 2 columns]

# %%
df2 = df.loc[ : , ['lat','lon']]

# %%
st.map(df2 , zoom=100)

# %%
df=df.rename(columns={'위도':'lat','경도':'lon'})
# Out:
# ------------------------------------------------------------------------
# AttributeError                         Traceback (most recent call last)
# Cell In [47], line 1
# ----> 1 df=df.rename(columns={'위도':'lat','경도':'lon'}).type
#
# File ~\anaconda3\envs\YH\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
type(df['lat'][1])
# Out:
# numpy.float64

# %%
x
# Out:
# 0       37.788938
# 1       37.840847
# 2       37.840949
# 3       37.747333
# 4       37.743691
#           ...
# 1344    37.211213
# 1345    37.217753
# 1346    37.116396
# 1347    37.249533
# 1348    37.213417
# Name: 위도, Length: 1349, dtype: float64

# %%
y=df['경도']

# %%
import folium
center=[37.541,126.986]
m=folium.map(location=center,zoom_start=11)
m
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# Cell In [34], line 3
#       1 import folium
#       2 center=[37.541,126.986]
# ----> 3 m=folium.map(location=center,zoom_start=11)
#       4 m
#
# TypeError: 'module' object is not callable

# %%
center=[37.541,126.986]
m=folium.map(location=center,zoom_start=10)
m
# Out:
# ------------------------------------------------------------------------
# TypeError                              Traceback (most recent call last)
# Cell In [32], line 2
#       1 center=[37.541,126.986]
# ----> 2 m=folium.map(location=center,zoom_start=10)
#       3 m
#
# TypeError: 'module' object is not callable
